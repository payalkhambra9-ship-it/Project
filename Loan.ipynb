# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
#file ko read karne ke liye
df=pd.read_csv('loan_data.csv')

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
# inforamation ke lie
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  str
#  2   person_education                45000 non-null  str
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  str
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  str
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
#feactuers ke liye
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='str')

# %%
# kisi 1 column ko nikalne ke liye
df.person_age
# Out:
# 0        22.0
# 1        21.0
# 2        25.0
# 3        23.0
# 4        24.0
#          ...
# 44995    27.0
# 44996    37.0
# 44997    33.0
# 44998    29.0
# 44999    24.0
# Name: person_age, Length: 45000, dtype: float64

# %%
df['person_age']
# Out:
# 0        22.0
# 1        21.0
# 2        25.0
# 3        23.0
# 4        24.0
#          ...
# 44995    27.0
# 44996    37.0
# 44997    33.0
# 44998    29.0
# 44999    24.0
# Name: person_age, Length: 45000, dtype: float64

# %%
df[['person_age']]
# Out:
#        person_age
# 0            22.0
# 1            21.0
# 2            25.0
# 3            23.0
# 4            24.0
# ...           ...
# 44995        27.0
# 44996        37.0
# 44997        33.0
# 44998        29.0
# 44999        24.0
#
# [45000 rows x 1 columns]

# %%
#upper se 5 value ke liye
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
#niche ki 5 value ke lie
df.tail()
# Out:
#        person_age person_gender person_education  person_income  \
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# ...

# %%
#duplocate value ke liye matlab ki uniqe row kitni h agar row uniqe h to false or agar reapet h to true
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44995    False
# 44996    False
# 44997    False
# 44998    False
# 44999    False
# Length: 45000, dtype: bool

# %%
#duplicated value ka sum
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# duplicate row dekhne ke liye
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [person_age, person_gender, person_education, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %%
#drop duplicate value
df.drop_duplicates()
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44995    False
# 44996    False
# 44997    False
# 44998    False
# 44999    False
# Length: 45000, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#null value check ke liye
df.isnull()
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0           False          False             False          False
# 1           False          False             False          False
# 2           False          False             False          False
# 3           False          False             False          False
# 4           False          False             False          False
# ...           ...            ...               ...            ...
# 44995       False          False             False          False
# 44996       False          False             False          False
# 44997       False          False             False          False
# 44998       False          False             False          False
# 44999       False          False             False          False
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               False                  False      False        False
# ...

# %%
#sum of null value
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
#drop null value 
df.dropna(inplace=True)

# %%
df.isnull()
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0           False          False             False          False
# 1           False          False             False          False
# 2           False          False             False          False
# 3           False          False             False          False
# 4           False          False             False          False
# ...           ...            ...               ...            ...
# 44995       False          False             False          False
# 44996       False          False             False          False
# 44997       False          False             False          False
# 44998       False          False             False          False
# 44999       False          False             False          False
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               False                  False      False        False
# ...

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
#string data ko select karne ke lie
char=df.select_dtypes(include="O")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22836\2706094488.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char=df.select_dtypes(include="O")

# %%
char
# Out:
#       person_gender person_education person_home_ownership        loan_intent  \
# 0            female           Master                  RENT           PERSONAL
# 1            female      High School                   OWN          EDUCATION
# 2            female      High School              MORTGAGE            MEDICAL
# 3            female         Bachelor                  RENT            MEDICAL
# 4              male           Master                  RENT            MEDICAL
# ...             ...              ...                   ...                ...
# 44995          male        Associate                  RENT            MEDICAL
# 44996        female        Associate                  RENT    HOMEIMPROVEMENT
# 44997          male        Associate                  RENT  DEBTCONSOLIDATION
# 44998          male         Bachelor                  RENT          EDUCATION
# 44999          male      High School                  RENT  DEBTCONSOLIDATION
#
# ...

# %%
# select integer data type
int=df.select_dtypes(exclude='O')

# %%
int
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0            22.0        71948.0               0    35000.0          16.02
# 1            21.0        12282.0               0     1000.0          11.14
# 2            25.0        12438.0               3     5500.0          12.87
# 3            23.0        79753.0               0    35000.0          15.23
# 4            24.0        66135.0               1    35000.0          14.27
# ...           ...            ...             ...        ...            ...
# 44995        27.0        47971.0               6    15000.0          15.66
# 44996        37.0        65800.0              17     9000.0          14.07
# 44997        33.0        56942.0               7     2771.0          10.02
# 44998        29.0        33164.0               4    12000.0          13.23
# 44999        24.0        51609.0               1     6665.0          17.05
#
# ...

# %%
#column ki unique value ke liye
df['loan_intent'].unique()
# Out:
# <StringArray>
# [         'PERSONAL',         'EDUCATION',           'MEDICAL',
#            'VENTURE',   'HOMEIMPROVEMENT', 'DEBTCONSOLIDATION']
# Length: 6, dtype: str

# %%
#count number of uniqe value
df['loan_intent'].nunique()
# Out:
# 6

# %%
#uniqe value count ke liy
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
#drop 1 column
# df.drop('person_home_ownership',axis=1,inplace=True)

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
# 2 drop karne ke liy
#df.drop(['person_home_ownership','person_age'],axis=1,inplace=True)

# %%
df.drop(['loan_intent','previous_loan_defaults_on_file'],axis=1,inplace=True)

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt  loan_int_rate  \
# 0                   0                  RENT    35000.0          16.02
# ...

# %%
#query find out karne ke liy
df[df['person_gender']=='male']
# Out:
#        person_age person_gender person_education  person_income  \
# 4            24.0          male           Master        66135.0
# 12           23.0          male         Bachelor       114860.0
# 13           26.0          male           Master       130713.0
# 16           23.0          male         Bachelor       144943.0
# 18           23.0          male         Bachelor       136628.0
# ...           ...           ...              ...            ...
# 44991        24.0          male      High School        37786.0
# 44995        27.0          male        Associate        47971.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt  loan_int_rate  \
# 4                   1                  RENT    35000.0          14.27
# ...

# %%
#encoding ke liye
df['person_education'].unique()
# Out:
# <StringArray>
# ['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate']
# Length: 5, dtype: str

# %%
person_edu={
    'Master':1, 'High School':2, 'Bachelor':3, 'Associate':4, 'Doctorate':5

}

# %%
df['person_education']=df['person_education'].map(person_edu)

# %%
df
# Out:
#        person_age person_gender  person_education  person_income  \
# 0            22.0        female                 1        71948.0
# 1            21.0        female                 2        12282.0
# 2            25.0        female                 2        12438.0
# 3            23.0        female                 3        79753.0
# 4            24.0          male                 1        66135.0
# ...           ...           ...               ...            ...
# 44995        27.0          male                 4        47971.0
# 44996        37.0        female                 4        65800.0
# 44997        33.0          male                 4        56942.0
# 44998        29.0          male                 3        33164.0
# 44999        24.0          male                 2        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt  loan_int_rate  \
# 0                   0                  RENT    35000.0          16.02
# ...

# %%
df['person_gender'].unique()
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
gender_dict={
    'female':1, 'male':2
}

# %%
df['person_gender']=df['person_gender'].map(gender_dict)

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0            22.0              1                 1        71948.0
# 1            21.0              1                 2        12282.0
# 2            25.0              1                 2        12438.0
# 3            23.0              1                 3        79753.0
# 4            24.0              2                 1        66135.0
# ...           ...            ...               ...            ...
# 44995        27.0              2                 4        47971.0
# 44996        37.0              1                 4        65800.0
# 44997        33.0              2                 4        56942.0
# 44998        29.0              2                 3        33164.0
# 44999        24.0              2                 2        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt  loan_int_rate  \
# 0                   0                  RENT    35000.0          16.02
# ...

# %%
df['person_home_ownership'].unique()
# Out:
# <StringArray>
# ['RENT', 'OWN', 'MORTGAGE', 'OTHER']
# Length: 4, dtype: str

# %%
person_home_ownership_dict={
    'RENT':1, 'OWN':2, 'MORTGAGE':3, 'OTHER':4
}

# %%
df['person_home_ownership']=df['person_home_ownership'].map(person_home_ownership_dict)

# %%
x=df.drop('person_income',axis=1)

# %%
x
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 0            22.0              1                 1               0
# 1            21.0              1                 2               0
# 2            25.0              1                 2               3
# 3            23.0              1                 3               0
# 4            24.0              2                 1               1
# ...           ...            ...               ...             ...
# 44995        27.0              2                 4               6
# 44996        37.0              1                 4              17
# 44997        33.0              2                 4               7
# 44998        29.0              2                 3               4
# 44999        24.0              2                 2               1
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 0                          1    35000.0          16.02                 0.49
# ...

# %%
y=df[['person_income']]

# %%
y
# Out:
#        person_income
# 0            71948.0
# 1            12282.0
# 2            12438.0
# 3            79753.0
# 4            66135.0
# ...              ...
# 44995        47971.0
# 44996        65800.0
# 44997        56942.0
# 44998        33164.0
# 44999        51609.0
#
# [45000 rows x 1 columns]

# %%
# df.to_csv('clean loan_data.csv')

# %%
x
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 0            22.0              1                 1               0
# 1            21.0              1                 2               0
# 2            25.0              1                 2               3
# 3            23.0              1                 3               0
# 4            24.0              2                 1               1
# ...           ...            ...               ...             ...
# 44995        27.0              2                 4               6
# 44996        37.0              1                 4              17
# 44997        33.0              2                 4               7
# 44998        29.0              2                 3               4
# 44999        24.0              2                 2               1
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 0                          1    35000.0          16.02                 0.49
# ...

# %%
y
# Out:
#        person_income
# 0            71948.0
# 1            12282.0
# 2            12438.0
# 3            79753.0
# 4            66135.0
# ...              ...
# 44995        47971.0
# 44996        65800.0
# 44997        56942.0
# 44998        33164.0
# 44999        51609.0
#
# [45000 rows x 1 columns]

# %%
! pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn as sns

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test =train_test_split(x , y , test_size=0.2, random_state= 42)

# %%
print(x_train.shape, x_test.shape , y_train.shape ,y_test.shape)
# Out:
# (36000, 11) (9000, 11) (36000, 1) (9000, 1)

# %%
x_train
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 25180        34.0              1                 3              11
# 12555        25.0              2                 2               3
# 29153        41.0              1                 1              18
# 23838        27.0              2                 4               4
# 35686        27.0              2                 1               7
# ...           ...            ...               ...             ...
# 11284        26.0              2                 2               6
# 44732        25.0              1                 2               3
# 38158        33.0              1                 4               9
# 860          26.0              2                 1               6
# 15795        26.0              1                 2               4
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 25180                      3    15000.0          12.73                 0.15
# ...

# %%
y_train
# Out:
#        person_income
# 25180        97265.0
# 12555        72953.0
# 29153       322597.0
# 23838        94232.0
# 35686        84873.0
# ...              ...
# 11284        88451.0
# 44732        34772.0
# 38158        58317.0
# 860         178602.0
# 15795       210894.0
#
# [36000 rows x 1 columns]

# %%
x_test
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 37979        32.0              2                 4              10
# 9911         24.0              2                 4               6
# 43386        22.0              1                 1               0
# 13822        23.0              1                 3               1
# 44810        42.0              2                 2              20
# ...           ...            ...               ...             ...
# 14572        21.0              2                 3               0
# 30384        39.0              2                 2              17
# 36665        24.0              1                 1               1
# 30569        38.0              2                 4              16
# 5321         25.0              1                 2               0
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 37979                      3     7500.0           6.04                 0.08
# ...

# %%
y_test
# Out:
#        person_income
# 37979        96865.0
# 9911         56838.0
# 43386        37298.0
# 13822        39944.0
# 44810        67974.0
# ...              ...
# 14572       133205.0
# 30384        61889.0
# 36665        78950.0
# 30569        37142.0
# 5321         35216.0
#
# [9000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0            22.0              1                 1        71948.0
# 1            21.0              1                 2        12282.0
# 2            25.0              1                 2        12438.0
# 3            23.0              1                 3        79753.0
# 4            24.0              2                 1        66135.0
# ...           ...            ...               ...            ...
# 44995        27.0              2                 4        47971.0
# 44996        37.0              1                 4        65800.0
# 44997        33.0              2                 4        56942.0
# 44998        29.0              2                 3        33164.0
# 44999        24.0              2                 2        51609.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_int_rate  \
# 0                   0                      1    35000.0          16.02
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 37979        32.0              2                 4              10
# 9911         24.0              2                 4               6
# 43386        22.0              1                 1               0
# 13822        23.0              1                 3               1
# 44810        42.0              2                 2              20
# ...           ...            ...               ...             ...
# 14572        21.0              2                 3               0
# 30384        39.0              2                 2              17
# 36665        24.0              1                 1               1
# 30569        38.0              2                 4              16
# 5321         25.0              1                 2               0
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 37979                      3     7500.0           6.04                 0.08
# ...

# %%
pred=lr.predict(x_test)

# %%
lst=[32.0,	2	,4	,10	,3,	7500.0,	6.04,	0.08	,10.0,	601	,0]

# %%
lr.predict([lst])
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[104914.43274257]])

# %%
pred
# Out:
# array([[104914.43274257],
#        [ 53692.75712029],
#        [ 36037.0415025 ],
#        ...,
#        [ 79120.5286892 ],
#        [ 33740.05304821],
#        [ 10649.22972226]], shape=(9000, 1))

# %%
y_test
# Out:
#        person_income
# 37979        96865.0
# 9911         56838.0
# 43386        37298.0
# 13822        39944.0
# 44810        67974.0
# ...              ...
# 14572       133205.0
# 30384        61889.0
# 36665        78950.0
# 30569        37142.0
# 5321         35216.0
#
# [9000 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rfg =RandomForestRegressor()

# %%
rfg.fit(x_train,y_train)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
lst=[[32.0,	2	,4	,10	,3,	7500.0,	6.04,	0.08	,10.0,	601	,0]]
rfg.predict(lst)
# Out:
# c:\Users\hp\Desktop\Data science\liet_data\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([94596.26])

# %%
x_test
# Out:
#        person_age  person_gender  person_education  person_emp_exp  \
# 37979        32.0              2                 4              10
# 9911         24.0              2                 4               6
# 43386        22.0              1                 1               0
# 13822        23.0              1                 3               1
# 44810        42.0              2                 2              20
# ...           ...            ...               ...             ...
# 14572        21.0              2                 3               0
# 30384        39.0              2                 2              17
# 36665        24.0              1                 1               1
# 30569        38.0              2                 4              16
# 5321         25.0              1                 2               0
#
#        person_home_ownership  loan_amnt  loan_int_rate  loan_percent_income  \
# 37979                      3     7500.0           6.04                 0.08
# ...

# %%
pred =rfg.predict(x_test)

# %%
pred
# Out:
# array([94596.26, 56428.71, 38882.65, ..., 77728.8 , 36462.04, 35274.11],
#       shape=(9000,))

# %%
y_test
# Out:
#        person_income
# 37979        96865.0
# 9911         56838.0
# 43386        37298.0
# 13822        39944.0
# 44810        67974.0
# ...              ...
# 14572       133205.0
# 30384        61889.0
# 36665        78950.0
# 30569        37142.0
# 5321         35216.0
#
# [9000 rows x 1 columns]
